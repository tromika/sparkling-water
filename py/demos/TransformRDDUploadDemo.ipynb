# %%
# import packages
import h2o
import sparkling_water as sw
from pyspark import SparkConf, SparkContext

# %%
# create spark context 
conf = (SparkConf()
        .setMaster("local")
        .setAppName("My app")
        .set("spark.executor.memory", "512mb"))
sc = SparkContext(conf=conf)

# connect to existing h2o cluster
ip="192.168.0.14"
port=54323
h2o.init(ip=ip,port=port)
# Out:
# Warning: Version mismatch. H2O is version 3.1.0.99999, but the python package is version 3.0.1.4.
# <div style="overflow:auto"><table style="width:50%"><tr><td>H2O cluster uptime: </td>
# <td>2 hours 19 minutes 29 seconds 45 milliseconds </td></tr>
# <tr><td>H2O cluster version: </td>
# <td>3.1.0.99999</td></tr>
# <tr><td>H2O cluster name: </td>
# <td>sparkling-water-kuba</td></tr>
# <tr><td>H2O cluster total nodes: </td>
# <td>1</td></tr>
# <tr><td>H2O cluster total memory: </td>
# <td>504.5 MB</td></tr>
# <tr><td>H2O cluster total cores: </td>
# <td>4</td></tr>
# <tr><td>H2O cluster allowed cores: </td>
# <td>4</td></tr>
# <tr><td>H2O cluster healthy: </td>
# <td>True</td></tr>
# <tr><td>H2O Connection ip: </td>
# <td>192.168.0.14</td></tr>
# <tr><td>H2O Connection port: </td>
# <td>54323</td></tr></table></div>

# %%
# create rdd
data = [1, 2, 3, 4, 5]
distData = sc.parallelize(data)

# %%
h2o_frame = sw.Utils.import_frame_from_rdd(distData)
# Out:
# ---------------------------------------------------------------------------
# EnvironmentError                          Traceback (most recent call last)
# <ipython-input-4-c10fe1da4332> in <module>()
# ----> 1 h2o_frame = sw.Utils.import_frame_from_rdd(distData)
#
# /home/kuba/devel-h2o/sparkling-water/py/sparkling_water/utils.pyc in import_frame_from_rdd(rdd)
#      27         for item in list:
#      28             tmpfile.write("%s\n" % item)
# ---> 29         h2o_frame = h2o.import_frame(path=h2o.locate(tmpfile.name))
#      30         #tmpfile.close()
#      31         return h2o_frame
#
# /usr/local/lib/python2.7/dist-packages/h2o/h2o.pyc in import_frame(path)
#      58   :return: A new H2OFrame
#      59   """
# ---> 60   return H2OFrame(file_path=path)
#      61
#      62
#
# /usr/local/lib/python2.7/dist-packages/h2o/frame.pyc in __init__(self, python_obj, file_path, raw_id, expr)
#      43     if expr is not None:         self._ast = expr
#      44     elif python_obj is not None: self._upload_python_object(python_obj)
# ---> 45     elif file_path is not None:  self._import_parse(file_path)
#      46     elif raw_id is not None:     self._handle_text_key(raw_id)
#      47     else: pass
#
# /usr/local/lib/python2.7/dist-packages/h2o/frame.pyc in _import_parse(self, file_path)
#      62
#      63   def _import_parse(self,file_path):
# ---> 64     rawkey = h2o.import_file(file_path)
#      65     setup = h2o.parse_setup(rawkey)
#      66     parse = h2o.parse(setup, _py_tmp_key())  # create a new key
#
# /usr/local/lib/python2.7/dist-packages/h2o/h2o.pyc in import_file(path)
#      29   """
#      30   paths = [path] if isinstance(path,str) else path
# ---> 31   return [ _import1(fname) for fname in paths ]
#      32
#      33 def _import1(path):
#
# /usr/local/lib/python2.7/dist-packages/h2o/h2o.pyc in _import1(path)
#      32
#      33 def _import1(path):
# ---> 34   j = H2OConnection.get_json(url_suffix="ImportFiles", path=path)
#      35   if j['fails']:
#      36     raise ValueError("ImportFiles of " + path + " failed on " + j['fails'])
#
# /usr/local/lib/python2.7/dist-packages/h2o/connection.pyc in get_json(url_suffix, **kwargs)
#     398     if __H2OCONN__ is None:
#     399       raise ValueError("No h2o connection. Did you run `h2o.init()` ?")
# --> 400     return __H2OCONN__._rest_json(url_suffix, "GET", None, **kwargs)
#     401
#     402   @staticmethod
#
# /usr/local/lib/python2.7/dist-packages/h2o/connection.pyc in _rest_json(self, url_suffix, method, file_upload_info, **kwargs)
#     407
#     408   def _rest_json(self, url_suffix, method, file_upload_info, **kwargs):
# --> 409     raw_txt = self._do_raw_rest(url_suffix, method, file_upload_info, **kwargs)
#     410     return self._process_tables(raw_txt.json())
#     411
#
# /usr/local/lib/python2.7/dist-packages/h2o/connection.pyc in _do_raw_rest(self, url_suffix, method, file_upload_info, **kwargs)
#     481       raise EnvironmentError(("h2o-py got an unexpected HTTP status code:\n {} {} (method = {}; url = {}). \n"+ \
#     482                               "detailed error messages: {}")
# --> 483                              .format(http_result.status_code,http_result.reason,method,url,detailed_error_msgs))
#     484
#     485
#
# EnvironmentError: h2o-py got an unexpected HTTP status code:
#  404 Not Found (method = GET; url = http://192.168.0.14:54323/3/ImportFiles?path=/tmp/tmpzVDIM0).
# detailed error messages: File /tmp/tmpzVDIM0 does not exist

# %%
h2o_frame.describe()
# Out:
# Rows: 1,192 Cols: 117
#
# Chunk compression summary:
# <div style="overflow:auto"><table style="width:50%"><tr><td>chunk_type</td>
# <td>chunk_name</td>
# <td>count</td>
# <td>count_percentage</td>
# <td>size</td>
# <td>size_percentage</td></tr>
# <tr><td>C0D</td>
# <td>Constant Reals</td>
# <td>114</td>
# <td>97.4359</td>
# <td>    8.9 KB</td>
# <td>64.717575</td></tr>
# <tr><td>C1</td>
# <td>1-Byte Integers</td>
# <td>2</td>
# <td>1.7094018</td>
# <td>    2.5 KB</td>
# <td>17.882486</td></tr>
# <tr><td>C2</td>
# <td>2-Byte Integers</td>
# <td>1</td>
# <td>0.8547009</td>
# <td>    2.4 KB</td>
# <td>17.399942</td></tr></table></div>
# Frame distribution summary:
# <div style="overflow:auto"><table style="width:50%"><tr><td></td>
# <td>size</td>
# <td>number_of_rows</td>
# <td>number_of_chunks_per_column</td>
# <td>number_of_chunks</td></tr>
# <tr><td>192.168.0.14:54321</td>
# <td>   13.8 KB</td>
# <td>1192.0</td>
# <td>1.0</td>
# <td>117.0</td></tr>
# <tr><td>mean</td>
# <td>   13.8 KB</td>
# <td>1192.0</td>
# <td>1.0</td>
# <td>117.0</td></tr>
# <tr><td>min</td>
# <td>   13.8 KB</td>
# <td>1192.0</td>
# <td>1.0</td>
# <td>117.0</td></tr>
# <tr><td>max</td>
# <td>   13.8 KB</td>
# <td>1192.0</td>
# <td>1.0</td>
# <td>117.0</td></tr>
# <tr><td>stddev</td>
# <td>      0  B</td>
# <td>0.0</td>
# <td>0.0</td>
# <td>0.0</